# %% [markdown]
# <a href="https://colab.research.google.com/github/pushpalatha2297/hds5210-2023/blob/main/week15/week15_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 15 Programming Assignment
#
# The final thing for this semester that we haven't exercised, yet, is working with databases through Python.  In thi final assignment of the semester, you will practice pulling data from either Google Big Query or Snowflake, loading that data into a Pandas data frame, summarizing the data, and then exporting that to an Excel file.
#
# **You will need to use your own Google Big Query or Snowflake account to run this notebook, but you should try to make it configurable so anyone with an account in those technologies could run your notebook with minimal changes.**
#
#
# Build a notebook with good comments (either in code or in markdown cells).  Then submit your assignment as usual.

# %% [markdown]
# ### 1. Connect to the data source
#
# Follow the examples provided in the [week15 folder of our GitHub repository](https://github.com/paulboal/hds5210-2023/tree/main/week15) to connect your notebook either to Big Query or Snowflake.

# %%
# !pip install "snowflake-connector-python[pandas]"
# Out:
# Requirement already satisfied: snowflake-connector-python[pandas] in /usr/local/lib/python3.10/dist-packages (3.6.0)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]) (1.5.1)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]) (1.16.0)
# Requirement already satisfied: cryptography<42.0.0,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]) (41.0.7)
# Requirement already satisfied: pyOpenSSL<24.0.0,>=16.2.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]) (23.3.0)
# Requirement already satisfied: pyjwt<3.0.0 in /usr/lib/python3/dist-packages (from snowflake-connector-python[pandas]) (2.3.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]) (2023.3.post1)
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]) (2.31.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]) (2023.11.17)
# Requirement already satisfied: typing-extensions<5,>=4.3 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]) (4.5.0)
# Requirement already satisfied: filelock<4,>=3.5 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]) (3.13.1)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]) (2.4.0)
# Requirement already satisfied: platformdirs<4.0.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]) (3.11.0)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]) (0.12.3)
# Requirement already satisfied: pandas<2.2.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]) (1.5.3)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]) (9.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python[pandas]) (2.21)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2.0,>=1.0.0->snowflake-connector-python[pandas]) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2.0,>=1.0.0->snowflake-connector-python[pandas]) (1.23.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0->snowflake-connector-python[pandas]) (2.0.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<2.2.0,>=1.0.0->snowflake-connector-python[pandas]) (1.16.0)

# %%
import pandas as pd

# %%
# Get user password
import getpass

# %%
pwd = getpass.getpass('Enter password')
# Out:
# Enter password··········

# %%
# Create connection to snowflake
import snowflake.connector
conn = snowflake.connector.connect(
    user = 'pushpalatha',
    password = str(pwd),
    account = 'QIRQICA-ZA87285'
)

# %% [markdown]
# ### 2. Query some data
#
# Assuming the source database has some data in it or that you can load some data into it from any source, query it.  Then, read that data into a Pandas dataframe.

# %%
# Create a variable called sql and specify a query that it will store
sql = 'select * from COVID19_EPIDEMIOLOGICAL_DATA.PUBLIC.CDC_POLICY_MEASURES '

# %%
#Execute the query using the python connector
res = conn.cursor().execute(sql).fetchall()
# Out:
# ERROR:snowflake.connector.result_batch:Failed to fetch the large result set batch data_0_0_0 for the 1 th time, backing off for 1s for the reason: ''No field numbered 1 is present in this asn1crypto.keys.PublicKeyInfo''
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/snowflake/connector/result_batch.py", line 332, in _download
#     response = session.request("get", **request_data)
#   File "/usr/local/lib/python3.10/dist-packages/snowflake/connector/vendored/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/snowflake/connector/vendored/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/snowflake/connector/vendored/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#   File "/usr/local/lib/python3.10/dist-packages/snowflake/connector/vendored/urllib3/connectionpool.py", line 715, in urlopen
#     httplib_response = self._make_request(
#   File "/usr/local/lib/python3.10/dist-packages/snowflake/connector/vendored/urllib3/connectionpool.py", line 404, in _make_request
#     self._validate_conn(conn)
#   File "/usr/local/lib/python3.10/dist-packages/snowflake/connector/vendored/urllib3/connectionpool.py", line 1058, in _validate_conn
#     conn.connect()
#   File "/usr/local/lib/python3.10/dist-packages/snowflake/connector/vendored/urllib3/connection.py", line 419, in connect
#     self.sock = ssl_wrap_socket(
#   File "/usr/local/lib/python3.10/dist-packages/snowflake/connector/ssl_wrap_socket.py", line 90, in ssl_wrap_socket_with_ocsp
#     ).validate(server_hostname, ret.connection)
#   File "/usr/local/lib/python3.10/dist-packages/snowflake/connector/ocsp_snowflake.py", line 995, in validate
#     return self._validate(
#   File "/usr/local/lib/python3.10/dist-packages/snowflake/connector/ocsp_snowflake.py", line 1008, in _validate
#     results = self._validate_certificates_sequential(
#   File "/usr/local/lib/python3.10/dist-packages/snowflake/connector/ocsp_snowflake.py", line 1190, in _validate_certificates_sequential
#     cert_id, _ = self.create_ocsp_request(issuer=issuer, subject=subject)
#   File "/usr/local/lib/python3.10/dist-packages/snowflake/connector/ocsp_asn1crypto.py", line 110, in create_ocsp_request
#     "issuer_key_hash": OctetString(issuer.public_key.sha1),
#   File "/usr/local/lib/python3.10/dist-packages/asn1crypto/keys.py", line 1271, in sha1
#     self._sha1 = hashlib.sha1(byte_cls(self['public_key'])).digest()
#   File "/usr/local/lib/python3.10/dist-packages/asn1crypto/core.py", line 3522, in __getitem__
#     raise KeyError(unwrap(
# KeyError: 'No field numbered 1 is present in this asn1crypto.keys.PublicKeyInfo'

# %%
#Run the same query, but this time use the read_sql method
# in the pandas data frame object
COVID19_DATA = pd.read_sql(sql, conn)
COVID19_DATA
# Out:
# <ipython-input-8-dc24a2da4f0c>:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   COVID19_DATA = pd.read_sql(sql, conn)
#      STATE_ID       COUNTY  FIPS_CODE POLICY_LEVEL       DATE  \
# 0          DE         None        NaN        state 2020-07-06
# 1          MS    Sunflower    28133.0       county 2020-07-20
# 2          PR         None        NaN        state 2020-06-15
# 3          MO         None        NaN        state 2020-06-15
# 4          DE         None        NaN        state 2020-09-05
# ...       ...          ...        ...          ...        ...
# 4212       IL         Cass    17017.0       county 2021-01-15
# 4213       NY     New York    36061.0       county 2020-06-08
# 4214       TX       Morris    48343.0       county 2020-07-03
# 4215       ME  Piscataquis    23021.0       county 2020-05-18
# 4216       WV         None        NaN        state 2020-03-19
#
#                    POLICY_TYPE START_STOP  \
# 0                      Phase 1       stop
# 1       Outdoor and Recreation       stop
# 2     Non-Essential Businesses       stop
# 3     Non-Essential Businesses       stop
# 4                      Phase 2       stop
# ...                        ...        ...
# 4212         Houses of Worship      start
# 4213  Non-Essential Businesses      start
# 4214          Mask Requirement      start
# 4215    Outdoor and Recreation      start
# 4216            Food and Drink      start
#
#                                                COMMENTS  \
# 0     Policy_Details: Governor Carney extended Delaw...
# 1     Policy_Details: Executive Order by Governor Ta...
# 2     Policy_Details: Retail - 50% \nPersonal Care -...
# 3     Policy_Details: All industries: practice socia...
# 4     Policy_Details: Governor Carney formally exten...
# ...                                                 ...
# 4212  Policy_Details: - All gatherings of 50 people ...
# 4213  Policy_Details: New York City (All counties) t...
# 4214  Policy_Details: County is approved to be exemp...
# 4215  Policy_Details: Rural Reopening :  wilderness ...
# 4216  Other measures and details for this policy inc...
#
#                                                  SOURCE  TOTAL_PHASE  \
# 0     sip_submission_form: https://governor.delaware...          NaN
# 1     sip_submission_form: https://www.sos.ms.gov/co...          NaN
# 2     sip_submission_form: https://www.estado.pr.gov...          NaN
# 3     sip_submission_form: https://health.mo.gov/liv...          NaN
# 4     sip_submission_form: https://governor.delaware...          NaN
# ...                                                 ...          ...
# 4212  sip_submission_form: https://coronavirus.illin...          5.0
# 4213  sip_submission_form: https://coronavirus.healt...          NaN
# 4214  sip_submission_form: https://tdem.texas.gov/ga...          NaN
# 4215  sip_submission_form: https://www.maine.gov/cov...          3.0
# 4216                  BU COVID-19 State Policy Database          NaN
#
#      ISO3166_1 ISO3166_2    LAST_UPDATE_DATE  LAST_REPORTED_FLAG
# 0           US        DE 2022-12-08 07:18:00                True
# 1           US        MS 2022-12-08 07:18:00                True
# 2           US        PR 2022-12-08 07:18:00                True
# 3           US        MO 2022-12-08 07:18:00                True
# 4           US        DE 2022-12-08 07:18:00                True
# ...        ...       ...                 ...                 ...
# 4212        US        IL 2022-12-08 07:18:00                True
# 4213        US        NY 2022-12-08 07:18:00                True
# 4214        US        TX 2022-12-08 07:18:00                True
# 4215        US        ME 2022-12-08 07:18:00                True
# 4216        US        WV 2022-12-08 07:18:00                True
#
# [4217 rows x 14 columns]

# %% [markdown]
# ### 3. Aggregate your data frame
#
# Do some kind of aggregation on your data frame.  Something that makes sense and has some groups to it.  Don't just sum up one column for the entire data frame.  Be more creative than that.

# %%
# Create a calculated field growth_rate and add it into the dataframe



# Assuming COVID19_DATA is your existing DataFrame
# Add a new column 'PolicyDateDescription' which combines 'DATE' and 'POLICY_TYPE'
COVID19_DATA['PolicyDateDescription'] = COVID19_DATA['DATE'].astype(str) + " - " + COVID19_DATA['POLICY_TYPE']

# Now, COVID19_DATA has an additional column 'PolicyDateDescription' with combined string values of 'DATE' and 'POLICY_TYPE'

COVID19_DATA
# Out:
#      STATE_ID       COUNTY  FIPS_CODE POLICY_LEVEL       DATE  \
# 0          DE         None        NaN        state 2020-07-06
# 1          MS    Sunflower    28133.0       county 2020-07-20
# 2          PR         None        NaN        state 2020-06-15
# 3          MO         None        NaN        state 2020-06-15
# 4          DE         None        NaN        state 2020-09-05
# ...       ...          ...        ...          ...        ...
# 4212       IL         Cass    17017.0       county 2021-01-15
# 4213       NY     New York    36061.0       county 2020-06-08
# 4214       TX       Morris    48343.0       county 2020-07-03
# 4215       ME  Piscataquis    23021.0       county 2020-05-18
# 4216       WV         None        NaN        state 2020-03-19
#
#                    POLICY_TYPE START_STOP  \
# 0                      Phase 1       stop
# 1       Outdoor and Recreation       stop
# 2     Non-Essential Businesses       stop
# 3     Non-Essential Businesses       stop
# 4                      Phase 2       stop
# ...                        ...        ...
# 4212         Houses of Worship      start
# 4213  Non-Essential Businesses      start
# 4214          Mask Requirement      start
# 4215    Outdoor and Recreation      start
# 4216            Food and Drink      start
#
#                                                COMMENTS  \
# 0     Policy_Details: Governor Carney extended Delaw...
# 1     Policy_Details: Executive Order by Governor Ta...
# 2     Policy_Details: Retail - 50% \nPersonal Care -...
# 3     Policy_Details: All industries: practice socia...
# 4     Policy_Details: Governor Carney formally exten...
# ...                                                 ...
# 4212  Policy_Details: - All gatherings of 50 people ...
# 4213  Policy_Details: New York City (All counties) t...
# 4214  Policy_Details: County is approved to be exemp...
# 4215  Policy_Details: Rural Reopening :  wilderness ...
# 4216  Other measures and details for this policy inc...
#
#                                                  SOURCE  TOTAL_PHASE  \
# 0     sip_submission_form: https://governor.delaware...          NaN
# 1     sip_submission_form: https://www.sos.ms.gov/co...          NaN
# 2     sip_submission_form: https://www.estado.pr.gov...          NaN
# 3     sip_submission_form: https://health.mo.gov/liv...          NaN
# 4     sip_submission_form: https://governor.delaware...          NaN
# ...                                                 ...          ...
# 4212  sip_submission_form: https://coronavirus.illin...          5.0
# 4213  sip_submission_form: https://coronavirus.healt...          NaN
# 4214  sip_submission_form: https://tdem.texas.gov/ga...          NaN
# 4215  sip_submission_form: https://www.maine.gov/cov...          3.0
# 4216                  BU COVID-19 State Policy Database          NaN
#
#      ISO3166_1 ISO3166_2    LAST_UPDATE_DATE  LAST_REPORTED_FLAG  \
# 0           US        DE 2022-12-08 07:18:00                True
# 1           US        MS 2022-12-08 07:18:00                True
# 2           US        PR 2022-12-08 07:18:00                True
# 3           US        MO 2022-12-08 07:18:00                True
# 4           US        DE 2022-12-08 07:18:00                True
# ...        ...       ...                 ...                 ...
# 4212        US        IL 2022-12-08 07:18:00                True
# 4213        US        NY 2022-12-08 07:18:00                True
# 4214        US        TX 2022-12-08 07:18:00                True
# 4215        US        ME 2022-12-08 07:18:00                True
# 4216        US        WV 2022-12-08 07:18:00                True
#
#                       PolicyDateDescription
# 0                      2020-07-06 - Phase 1
# 1       2020-07-20 - Outdoor and Recreation
# 2     2020-06-15 - Non-Essential Businesses
# 3     2020-06-15 - Non-Essential Businesses
# 4                      2020-09-05 - Phase 2
# ...                                     ...
# 4212         2021-01-15 - Houses of Worship
# 4213  2020-06-08 - Non-Essential Businesses
# 4214          2020-07-03 - Mask Requirement
# 4215    2020-05-18 - Outdoor and Recreation
# 4216            2020-03-19 - Food and Drink
#
# [4217 rows x 15 columns]

# %% [markdown]
# ### 4. Write to Excel
#
# Use Pandas functions to write your summarized data out to a local Excel file.

# %%
# Writing the dataframe to an excel file
COVID19_DATA.to_excel('COVID19_DATA.xlsx', index=False )

# %% [markdown]
# ---
#
# ## Submitting Your Work
#
# Submit your work as usual
